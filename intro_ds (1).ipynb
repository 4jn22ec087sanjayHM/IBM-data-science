# %% [markdown]
# # Data Science tool and Ecosystem

# %% [markdown]
# In this notebook Data Science Tools and Environment are Explained
#
# Some of the popular language Data scientist use are:
#
# 1.Python
# 2.R
# 3.SQL
# | Data Science libraries | Category |
# |--------------------|----------|
# | Numpy | Arithmatic solutions |
# | Pandas | Arithmatic solutions |
# | Seaborn | Visulaizing Data |
# | Matplotlib | Visualizing Data |
# | Scikit learn | Machine learning Tool |
#
#
#
# | Data Science Tools| Usage |
# |--------------------|----------|
# | Jupyter Notebook | Computation  |
# | VS code | Coding |
# |  Anaconda| Environment |
# | Apache hadoop  | Big Data |
# | Docker | Deployment |
#
#
#
#
#
#
#
#
#
#
#
#
#
# Arithmetic Expression Examples
# Below are a few examples of evaluating arithmetic expressions in Python.
# 1.Addition
# 2 + 3 = 5
#
# 2.Subtraction
# 10 - 4 = 6
#
# 3.Multiplication
# 6 * 3 = 18
#
# 4.Division
# 12 / 4 = 3
#
# 5.Exponent
# 2 ** 3 = 8

# %%
x=(3*4)+5
print(x)
# Out:
# 17

# %%
#this code will convert 200 minutes into hours 
x=200
y=float(x/60)
print(f"200 minutes is equal to {y} hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# Objectives:
#
# 1.List popular languages for Data Science
# 2.Identify commonly used Data Science libraries
# 3.Recognize tools used in Data Science
# 4.Demonstrate arithmetic expressions in Python
# 5.Create and format Markdown cells in Jupyter Notebook

# %% [markdown]
# # Author
# Sanjay HM
